# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = df.drop(columns='loan_status')
X = pd.get_dummies(X)

# Create our target
y = df['loan_status']

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# count   68817.000000  ...        68817.000000        68817.000000
# mean    17604.142828  ...            0.052138            2.219423
# std     21835.880400  ...            0.390633            1.897432
# min         0.000000  ...            0.000000            0.000000
# 25%      6293.000000  ...            0.000000            1.000000
# 50%     12068.000000  ...            0.000000            2.000000
# 75%     21735.000000  ...            0.000000            3.000000
# max    587191.000000  ...           18.000000           19.000000
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# count    68817.000000      68817.000000          68817.000000    68817.0
# mean        95.057627         30.626217              0.125972        0.0
# std          8.326426         33.631463              0.336732        0.0
# min         20.000000          0.000000              0.000000        0.0
# 25%         93.000000          0.000000              0.000000        0.0
# 50%        100.000000         20.000000              0.000000        0.0
# 75%        100.000000         50.000000              0.000000        0.0
# max        100.000000        100.000000              4.000000        0.0
#
#        tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# count     6.881700e+04       6.881700e+04    68817.000000
# mean      2.100332e+05       6.133843e+04    29734.128558
# std       1.928088e+05       5.738798e+04    26795.394232
# min       3.600000e+03       2.350000e+02      100.000000
# 25%       6.697700e+04       2.650300e+04    11600.000000
# 50%       1.467100e+05       4.535700e+04    22100.000000
# 75%       3.036400e+05       7.657000e+04    39300.000000
# max       3.292782e+06       1.295455e+06   509400.000000
#
#        total_il_high_credit_limit
# count                6.881700e+04
# mean                 5.572240e+04
# std                  5.095845e+04
# min                  1.270000e+02
# 25%                  2.288000e+04
# 50%                  4.200000e+04
# 75%                  7.249900e+04
# max                  1.426964e+06
#
# [8 rows x 76 columns]

# %%
# Check the balance of our target values
Counter(y)
# Out:
# Counter({'low_risk': 68470, 'high_risk': 347})

# %%
# Split the X and y into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=500, random_state=1)
rf = rf.fit(X_train_scaled, y_train)
predictions = rf.predict(X_test_scaled)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, predictions)
# Out:
# np.float64(0.6830221521918328)

# %%
# Display the confusion matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[   37,    64],
#        [    5, 17099]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.88      0.37      1.00      0.52      0.61      0.34       101
#    low_risk       1.00      1.00      0.37      1.00      0.61      0.39     17104
#
# avg / total       1.00      1.00      0.37      1.00      0.61      0.39     17205

# %%
# List the features sorted in descending order by feature importance
importances = rf.feature_importances_
sorted(zip(rf.feature_importances_, X.columns), reverse=True)
# Out:
# [(np.float64(0.07486922500536883), 'total_rec_int'),
#  (np.float64(0.06686220515014932), 'total_pymnt_inv'),
#  (np.float64(0.06573260493444634), 'total_rec_prncp'),
#  (np.float64(0.06380464409414062), 'last_pymnt_amnt'),
#  (np.float64(0.05475103896804395), 'total_pymnt'),
#  (np.float64(0.021471589076600003), 'installment'),
#  (np.float64(0.02111947211128395), 'out_prncp_inv'),
#  (np.float64(0.01926514456622541), 'out_prncp'),
#  (np.float64(0.01745217216062875), 'dti'),
#  (np.float64(0.01581677533386419), 'mo_sin_old_il_acct'),
#  (np.float64(0.015752096584564737), 'max_bal_bc'),
#  (np.float64(0.015735851725680147), 'mo_sin_old_rev_tl_op'),
#  (np.float64(0.015187632528247232), 'loan_amnt'),
#  (np.float64(0.014661307873711133), 'avg_cur_bal'),
#  (np.float64(0.014641247194838647), 'revol_bal'),
#  (np.float64(0.014412756323631721), 'bc_open_to_buy'),
#  (np.float64(0.014039446716687847), 'tot_hi_cred_lim'),
#  (np.float64(0.013856271832755807), 'total_bal_ex_mort'),
#  (np.float64(0.013846583703264598), 'total_bal_il'),
#  (np.float64(0.013719796384386343), 'bc_util'),
#  (np.float64(0.013499050487397083), 'tot_cur_bal'),
#  (np.float64(0.012511182679122197), 'int_rate'),
#  (np.float64(0.012490123493585824), 'total_bc_limit'),
#  (np.float64(0.012409321198802253), 'total_il_high_credit_limit'),
#  (np.float64(0.012336845696676767), 'total_rev_hi_lim'),
#  (np.float64(0.012319950198481611), 'annual_inc'),
#  (np.float64(0.012284595029129925), 'mths_since_rcnt_il'),
#  (np.float64(0.01211518987250945), 'total_rec_late_fee'),
#  (np.float64(0.01164238184510929), 'all_util'),
#  (np.float64(0.01160755237556143), 'total_acc'),
#  (np.float64(0.011170642950673803), 'il_util'),
#  (np.float64(0.011065665709193664), 'mths_since_recent_bc'),
#  (np.float64(0.010520112056421152), 'num_il_tl'),
#  (np.float64(0.010378274511558924), 'mths_since_recent_inq'),
#  (np.float64(0.010239087446039637), 'num_rev_accts'),
#  (np.float64(0.009797123499920048), 'acc_open_past_24mths'),
#  (np.float64(0.009646384803032508), 'issue_d_Mar-2019'),
#  (np.float64(0.009412754824617555), 'mo_sin_rcnt_rev_tl_op'),
#  (np.float64(0.008634884589019903), 'mo_sin_rcnt_tl'),
#  (np.float64(0.00859777972258021), 'pct_tl_nvr_dlq'),
#  (np.float64(0.008532043707315275), 'num_bc_tl'),
#  (np.float64(0.008512701527153), 'total_cu_tl'),
#  (np.float64(0.00845783526380756), 'inq_last_12m'),
#  (np.float64(0.008362431491176013), 'num_sats'),
#  (np.float64(0.008352284357764733), 'open_acc'),
#  (np.float64(0.008076364587270781), 'num_op_rev_tl'),
#  (np.float64(0.00770070884546264), 'num_actv_rev_tl'),
#  (np.float64(0.0075975969664543695), 'open_rv_24m'),
#  (np.float64(0.0074496959704872905), 'open_il_24m'),
#  (np.float64(0.007441913858165287), 'num_rev_tl_bal_gt_0'),
#  (np.float64(0.007128445000051126), 'num_bc_sats'),
#  (np.float64(0.00695828723798847), 'num_actv_bc_tl'),
#  (np.float64(0.0069533971458181605), 'inq_fi'),
#  (np.float64(0.006932552693242485), 'num_tl_op_past_12m'),
#  (np.float64(0.006550640022117912), 'mort_acc'),
#  (np.float64(0.006507756952000215), 'percent_bc_gt_75'),
#  (np.float64(0.006373612861460907), 'open_act_il'),
#  (np.float64(0.006257966191026999), 'open_acc_6m'),
#  (np.float64(0.0057450186937430875), 'next_pymnt_d_May-2019'),
#  (np.float64(0.005627299477383), 'open_rv_12m'),
#  (np.float64(0.005216941510319079), 'inq_last_6mths'),
#  (np.float64(0.00518970677697614), 'tot_coll_amt'),
#  (np.float64(0.005045667296097774), 'next_pymnt_d_Apr-2019'),
#  (np.float64(0.004986375663092396), 'issue_d_Feb-2019'),
#  (np.float64(0.004655388716554957), 'issue_d_Jan-2019'),
#  (np.float64(0.004194823636505581), 'open_il_12m'),
#  (np.float64(0.004004457692670987), 'delinq_2yrs'),
#  (np.float64(0.003537005320399146), 'num_accts_ever_120_pd'),
#  (np.float64(0.002784026437710506), 'pub_rec'),
#  (np.float64(0.0025974172728833473), 'pub_rec_bankruptcies'),
#  (np.float64(0.0022037942797172487), 'application_type_Individual'),
#  (np.float64(0.0021490750002533454), 'application_type_Joint App'),
#  (np.float64(0.002139901951259344), 'verification_status_Verified'),
#  (np.float64(0.0020225259078372267), 'verification_status_Source Verified'),
#  (np.float64(0.0018828963911996322), 'home_ownership_OWN'),
#  (np.float64(0.0018460511075793047), 'verification_status_Not Verified'),
#  (np.float64(0.001727966676900778), 'home_ownership_RENT'),
#  (np.float64(0.0017138462853079006), 'collections_12_mths_ex_med'),
#  (np.float64(0.0016446168290784192), 'num_tl_90g_dpd_24m'),
#  (np.float64(0.0016021004453811334), 'home_ownership_MORTGAGE'),
#  (np.float64(0.001487963519739227), 'initial_list_status_f'),
#  (np.float64(0.0012486838238359031), 'initial_list_status_w'),
#  (np.float64(0.0005756685930455276), 'home_ownership_ANY'),
#  (np.float64(0.00034778075781281636), 'chargeoff_within_12_mths'),
#  (np.float64(0.0), 'tax_liens'),
#  (np.float64(0.0), 'recoveries'),
#  (np.float64(0.0), 'pymnt_plan_n'),
#  (np.float64(0.0), 'policy_code'),
#  (np.float64(0.0), 'num_tl_30dpd'),
#  (np.float64(0.0), 'num_tl_120dpd_2m'),
#  (np.float64(0.0), 'hardship_flag_N'),
#  (np.float64(0.0), 'delinq_amnt'),
#  (np.float64(0.0), 'debt_settlement_flag_N'),
#  (np.float64(0.0), 'collection_recovery_fee'),
#  (np.float64(0.0), 'acc_now_delinq')]

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
from sklearn.ensemble import GradientBoostingClassifier

learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
for learning_rate in learning_rates:
    classifier = GradientBoostingClassifier(
        n_estimators=100,
        learning_rate=learning_rate,
        max_features=2,
        max_depth=3,
        random_state=1
    )

# Fit the model
classifier.fit(X_train_scaled, y_train.ravel())
print("Learning rate: ", learning_rate)
# Out:
# Learning rate:  1

# %%
# Calculated the balanced accuracy score
pred = classifier.predict(X_test_scaled)
balanced_accuracy_score(y_test, pred)
# Out:
# np.float64(0.6221189647028313)

# %%
# Display the confusion matrix
confusion_matrix(y_test, pred)
# Out:
# array([[   59,    42],
#        [ 5814, 11290]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.58      0.66      0.02      0.62      0.38       101
#    low_risk       1.00      0.66      0.58      0.79      0.62      0.39     17104
#
# avg / total       0.99      0.66      0.58      0.79      0.62      0.39     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
# Random Forest
#
# 2. Which model had the best recall score?
#
# Random Forest
#
# 3. Which model had the best geometric mean score?
#
# Easy Ensemble
#
# 4. What are the top three features?
#
# total_rec_int
# total_pymnt_inv
# total_pymnt
